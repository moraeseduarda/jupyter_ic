# %% [markdown]
# INVERTER 32nm CMOS
# - Tabela comparativa R^2, RMSE, MSE
#
# INVERTER 7nm FINFET
# - Tabela comparativa R^2, RMSE, MSE

# %%
import pandas as pd

path = "../outputs/not_32nm_cmos/results_mlps"

df = pd.read_csv(path)

# Show only 4 decimal places
df = df.round(4)

# %% [markdown]
# - DT: Decisicion Tree
# - RF: Random Forest
# - MLP-S-SKL: Scikit-Learn Single Output
# - MLP-M-SKL: Scikit-Learn	Multi-output
# -MLP-S-K: Keras Single Output
# - MLP-M-K: Keras Multi-output

# %% [markdown]
# ### DF & RF Result Tables

# %%
data = {
    'r2':   [0.9996, 0.9995, 0.9995, 0.9997, 0.9996, 0.9983],
    'rmse': [0.0038, 0.0035, 0.0135, 0.0032, 0.0028, 0.0106],
}

index = pd.MultiIndex.from_tuples([
    ('DT', 'tphl'),
    ('DT', 'tphl'),
    ('DT', 'corrent'),
    ('RF', 'tphl'),
    ('RF', 'tphl'),
    ('RF', 'corrent'),

], names=['model', 'target'])

df_Gabriel = pd.DataFrame(data, index=index)

df_invertido_Gabriel = df_Gabriel.T
df_invertido_Gabriel
# Out:
# model       DT                      RF
# target    tphl    tphl corrent    tphl    tphl corrent
# r2      0.9996  0.9995  0.9995  0.9997  0.9996  0.9983
# rmse    0.0038  0.0035  0.0135  0.0032  0.0028  0.0106

# %% [markdown]
# # INVERTER 32nm CMOS

# %% [markdown]
# ## All Results

# %%
df_invertido
# Out:
#             mlp_S_SKL | tphl mlp_S_SKL | tphl mlp_S_SKL | tplh  \
# target_name              val             test              val
# r2                    0.9997           0.9996           0.9993
# rmse                  0.0186            0.019           0.0265
# mse                   0.0003           0.0004           0.0007
#
#             mlp_S_SKL | tplh mlp_S_SKL | corrent mlp_S_SKL | corrent  \
# target_name             test                 val                test
# r2                    0.9993              0.9981              0.9981
# rmse                  0.0269              0.0436              0.0435
# mse                   0.0007              0.0019              0.0019
#
#             mlp_M_SKL | all mlp_M_SKL | all mlp_S_K | tphl mlp_S_K | tplh  \
# target_name             val            test            val            val
# r2                   0.9986          0.9986         0.9999         0.9987
# rmse                  0.036          0.0364         0.0114         0.0361
# mse                  0.0014          0.0014         0.0001         0.0013
#
#             mlp_S_K | corrent mlp_M_K | all
# target_name               val           val
# r2                     0.9968        0.9968
# rmse                   0.0565        0.0561
# mse                    0.0032        0.0032

# %% [markdown]
# ## Validation Results

# %%
# Results validation set
df_val = df[df['target_name'].str.endswith('val')].copy()
df_invertido = df_val.T
df_invertido
# Out:
#             mlp_S_SKL                 mlp_M_SKL mlp_S_K                  \
#                  tphl    tplh corrent       all    tphl    tplh corrent
# target_name       val     val     val       val     val     val     val
# r2             0.9997  0.9993  0.9981    0.9986  0.9999  0.9987  0.9968
# rmse           0.0186  0.0265  0.0436     0.036  0.0114  0.0361  0.0565
# mse            0.0003  0.0007  0.0019    0.0014  0.0001  0.0013  0.0032
#
#             mlp_M_K
#                 all
# target_name     val
# r2           0.9968
# rmse         0.0561
# mse          0.0032

# %%
# Save in figures/32nm_cmos/03_results/

# %% [markdown]
# ## Test Results

# %%
# Results test set
df_test = df[df['target_name'].str.endswith('test')].copy()
df_invertido = df_test.T
df_invertido

# %%
# Save in figures/32nm_cmos/03_results/
