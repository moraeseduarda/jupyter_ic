# %% [markdown]
# INVERTER 32nm CMOS
# - Tabela comparativa R^2, RMSE, MSE
#
# INVERTER 7nm FINFET
# - Tabela comparativa R^2, RMSE, MSE

# %%
import pandas as pd

path = "../outputs/not_32nm_cmos/results_mlps"

df = pd.read_csv(path)

# %%
# Results validation set
df_val = df[df['target_name'].str.endswith('val')].copy()

df_val
# Out:
#                   target_name        r2      rmse       mse
# mlp_S_SKL tphl            val  0.995513  0.067093  0.004501
#           tplh            val  0.996147  0.061261  0.003753
#           corrent         val  0.993025  0.083461  0.006966
# mlp_M_SKL all             val  0.994229  0.074693  0.005734
# mlp_S_K   tphl            val  0.998847  0.034011  0.001157
#           tplh            val  0.999017  0.030944  0.000958
#           corrent         val  0.996936  0.055321  0.003060
# mlp_M_K   all             val  0.995104  0.069055  0.004858

# %%
# Results test set
df_test = df[df['target_name'].str.endswith('test')].copy()

df_test
# Out:
#                   target_name        r2      rmse       mse
# mlp_S_SKL tphl           test  0.995431  0.068030  0.004628
#           tplh           test  0.996073  0.062579  0.003916
#           corrent        test  0.993060  0.083467  0.006967
# mlp_M_SKL all            test  0.994183  0.075527  0.005844

# %% [markdown]
# ## Validation Results MLP Using SKL e Keras 32nm not cmos

# %%
df_invertido = df_val.T
df_invertido
# Out:
#             mlp_S_SKL                     mlp_M_SKL   mlp_S_K            \
#                  tphl      tplh   corrent       all      tphl      tplh
# target_name       val       val       val       val       val       val
# r2           0.995513  0.996147  0.993025  0.994229  0.998847  0.999017
# rmse         0.067093  0.061261  0.083461  0.074693  0.034011  0.030944
# mse          0.004501  0.003753  0.006966  0.005734  0.001157  0.000958
# clean_name        val       val       val       val       val       val
#
#                         mlp_M_K
#               corrent       all
# target_name       val       val
# r2           0.996936  0.995104
# rmse         0.055321  0.069055
# mse           0.00306  0.004858
# clean_name        val       val

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/jupyter_ic/venv/lib/python3.12/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 11
#       8 temp = df_val['target_name'].str.replace(r"[\(\)\']", "", regex=True).str.split(',', expand=True)
#      10 df_val['Modelo'] = temp[0].str.strip()
# ---> 11 df_val['Alvo'] = temp[1].str.strip()
#      13 # 3. Criar a tabela invertida (Transpor)
#      14 # Selecionamos apenas as colunas que importam
#      15 df_final = df_val.set_index(['Modelo', 'Alvo'])[['r2', 'rmse', 'mse']].T
#
# File ~/jupyter_ic/venv/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/jupyter_ic/venv/lib/python3.12/site-packages/pandas/core/indexes/range.py:415, in RangeIndex.get_loc(self, key)
#     413         return self._range.index(new_key)
#     414     except ValueError as err:
# --> 415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
#     417     raise KeyError(key)
#
# KeyError: 1
