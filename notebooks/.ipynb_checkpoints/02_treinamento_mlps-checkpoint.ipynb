# %% [markdown]
# INVERTER 32nm CMOS data

# %%
import pandas as pd
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import backend as K

plots_dir = "../figures/32nm_cmos/"
K.clear_session()

# Carregando scalers
scaler_x = joblib.load('../data/processed/dados_32nm_cmos/scaler_x.pkl')
scaler_y = joblib.load('../data/processed/dados_32nm_cmos/scaler_y.pkl')

# Carregando os dados

X_train_sc = pd.read_csv('../data/processed/dados_32nm_cmos/X_train_sc.csv')
X_val_sc   = pd.read_csv('../data/processed/dados_32nm_cmos/X_val_sc.csv')
Xte_sc     = pd.read_csv('../data/processed/dados_32nm_cmos/X_test_sc.csv')

y_train_sc = pd.read_csv('../data/processed/dados_32nm_cmos/y_train_sc.csv')
y_val_sc   = pd.read_csv('../data/processed/dados_32nm_cmos/y_val_sc.csv')
yte_sc     = pd.read_csv('../data/processed/dados_32nm_cmos/y_test_sc.csv')

print(f"Training set loaded: {X_train_sc.shape}")
print(f"Validation set loaded: {X_val_sc.shape}")
print(f"Test set loaded: {Xte_sc.shape}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776565846.376926   66833 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1776565846.377386   66833 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1776565846.420001   66833 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776565847.478408   66833 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1776565847.478675   66833 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# Training set loaded: (64204, 7)
# Validation set loaded: (31624, 7)
# Test set loaded: (31943, 7)

# %% [markdown]
# # Multi-layer Perceptron (MPL)
# Neural network for supervised learning
#
# Idea:
# - Single-output model approach (Predicting one output at a time)
# - Multi-output model approach (Predicting three outputs at the same time)

# %% [markdown]
# Metrics
# - R² score (coefficient of determination) regression score function
# - RMSE and MSE error metrics

# %%
from sklearn.metrics import root_mean_squared_error, mean_squared_error
from sklearn.metrics import r2_score

# %%
scores = {}

# %%
def score(model, X, y, target_name, target_variable, target_set):
    pred = model.predict(X)
    r2 = r2_score(y, pred)
    rmse = root_mean_squared_error(y, pred)
    mse = mean_squared_error(y, pred)

    scores[target_name, target_variable, target_set] = {
        'r2': r2,
        'rmse': rmse,
        'mse': mse,
    }
    return scores[target_name, target_variable, target_set]

# %% [markdown]
# ## Multi-layer Perceptron for Regression using Scikit-Learn

# %%
from sklearn.neural_network import MLPRegressor

mlp_regressor= MLPRegressor(activation='relu',
                            solver = 'adam',
                            max_iter=500,
                            shuffle=True,
                            validation_fraction=0.1,
                            n_iter_no_change=10,
                            hidden_layer_sizes=(100, ),
                            early_stopping = True,
                            random_state=42,
                            verbose=True
                           )

# %% [markdown]
# ### Single-output models

# %% [markdown]
# #### Predicting TPHL

# %%
# Training
mlp_regressor.fit(X_train_sc, y_train_sc['tphl'])
# Out:
# Iteration 1, loss = 0.15237320
# Validation score: 0.925342
# Iteration 2, loss = 0.02146690
# Validation score: 0.975782
# Iteration 3, loss = 0.00706184
# Validation score: 0.991706
# Iteration 4, loss = 0.00294373
# Validation score: 0.995403
# Iteration 5, loss = 0.00183896
# Validation score: 0.996948
# Iteration 6, loss = 0.00132350
# Validation score: 0.997474
# Iteration 7, loss = 0.00102599
# Validation score: 0.998232
# Iteration 8, loss = 0.00081619
# Validation score: 0.998583
# Iteration 9, loss = 0.00067888
# Validation score: 0.998788
# Iteration 10, loss = 0.00057509
# Validation score: 0.999004
# Iteration 11, loss = 0.00050276
# Validation score: 0.999074
# Iteration 12, loss = 0.00043668
# Validation score: 0.999220
# Iteration 13, loss = 0.00039507
# Validation score: 0.999256
# Iteration 14, loss = 0.00035602
# Validation score: 0.999372
# Iteration 15, loss = 0.00031908
# Validation score: 0.999418
# Iteration 16, loss = 0.00029313
# Validation score: 0.999461
# Iteration 17, loss = 0.00027832
# Validation score: 0.999445
# Iteration 18, loss = 0.00026463
# Validation score: 0.999522
# Iteration 19, loss = 0.00026173
# Validation score: 0.999516
# Iteration 20, loss = 0.00024178
# Validation score: 0.999553
# Iteration 21, loss = 0.00023099
# Validation score: 0.999502
# Iteration 22, loss = 0.00022908
# Validation score: 0.999575
# Iteration 23, loss = 0.00021723
# Validation score: 0.999619
# Iteration 24, loss = 0.00020279
# Validation score: 0.999644
# Iteration 25, loss = 0.00019991
# Validation score: 0.999624
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(early_stopping=True, max_iter=500, random_state=42, verbose=True)

# %%
print(mlp_regressor.out_activation_)
print(mlp_regressor.loss_)
# Out:
# identity
# 0.00019990782067936497

# %%
# Validation
y_pred_sc = mlp_regressor.predict(X_val_sc)

# %%
# Validation R² score
mlp_regressor.score(X_val_sc, y_val_sc['tphl'])
# Out:
# 0.9996557275862706

# %%
# Validation error
rmse = root_mean_squared_error(y_val_sc['tphl'], y_pred_sc)
mse = mean_squared_error(y_val_sc['tphl'], y_pred_sc)
print(f'clf: MLP, RMSE: {rmse}')
print(f'clf: MLP, MSE {mse}')
# Out:
# clf: MLP, RMSE: 0.018585350948205393
# clf: MLP, MSE 0.00034541526986795916

# %%
score(mlp_regressor, X_val_sc, y_val_sc['tphl'], 'mlp_S_SKL', 'tphl', 'val')
# Out:
# {'r2': 0.9996557275862706,
#  'rmse': 0.018585350948205393,
#  'mse': 0.00034541526986795916}

# %%
# Testing
y_test_pred_sc = mlp_regressor.predict(Xte_sc)

# %%
# Testing R² score
mlp_regressor.score(Xte_sc, yte_sc['tphl'])
# Out:
# 0.9996425283681345

# %%
# Testing error
rmse = root_mean_squared_error(yte_sc['tphl'], y_test_pred_sc)
mse = mean_squared_error(yte_sc['tphl'], y_test_pred_sc)
print(f'clf: MLP, RMSE: {rmse}')
print(f'clf: MLP, MSE {mse}')
# Out:
# clf: MLP, RMSE: 0.019029553731250225
# clf: MLP, MSE 0.00036212391521053935

# %%
score(mlp_regressor, Xte_sc, yte_sc['tphl'], 'mlp_S_SKL', 'tphl', 'test')
# Out:
# {'r2': 0.9996425283681345,
#  'rmse': 0.019029553731250225,
#  'mse': 0.00036212391521053935}

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=y_pred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=y_val_sc['tphl'], label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -SKL Validation, TpHL')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=y_test_pred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=yte_sc['tphl'], label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -SKL Testing, TpHL')
ax.legend()
plt.show()

# %% [markdown]
# #### Predicting TPLH

# %%
# Training
mlp_regressor.fit(X_train_sc, y_train_sc['tplh'])
# Out:
# Iteration 1, loss = 0.12928024
# Validation score: 0.893096
# Iteration 2, loss = 0.03370267
# Validation score: 0.963444
# Iteration 3, loss = 0.01172078
# Validation score: 0.986993
# Iteration 4, loss = 0.00457722
# Validation score: 0.993827
# Iteration 5, loss = 0.00240328
# Validation score: 0.996306
# Iteration 6, loss = 0.00145465
# Validation score: 0.997655
# Iteration 7, loss = 0.00096617
# Validation score: 0.998317
# Iteration 8, loss = 0.00072916
# Validation score: 0.998652
# Iteration 9, loss = 0.00059742
# Validation score: 0.998930
# Iteration 10, loss = 0.00052827
# Validation score: 0.999026
# Iteration 11, loss = 0.00048247
# Validation score: 0.999092
# Iteration 12, loss = 0.00045091
# Validation score: 0.999134
# Iteration 13, loss = 0.00043133
# Validation score: 0.999184
# Iteration 14, loss = 0.00040914
# Validation score: 0.999223
# Iteration 15, loss = 0.00039921
# Validation score: 0.999229
# Iteration 16, loss = 0.00038880
# Validation score: 0.999269
# Iteration 17, loss = 0.00038600
# Validation score: 0.999303
# Iteration 18, loss = 0.00037504
# Validation score: 0.999292
# Iteration 19, loss = 0.00037778
# Validation score: 0.999266
# Iteration 20, loss = 0.00036140
# Validation score: 0.999290
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(early_stopping=True, max_iter=500, random_state=42, verbose=True)

# %%
print(mlp_regressor.out_activation_)
print(mlp_regressor.loss_)
# Out:
# identity
# 0.000361401295658909

# %%
# Validation
y_pred_sc = mlp_regressor.predict(X_val_sc)

# %%
# Validation R² score
mlp_regressor.score(X_val_sc, y_val_sc['tplh'])
# Out:
# 0.9992768533307875

# %%
# Validation error
rmse = root_mean_squared_error(y_val_sc['tplh'], y_pred_sc)
mse = mean_squared_error(y_val_sc['tplh'], y_pred_sc)
print(f'clf: MLP, RMSE: {rmse}')
print(f'clf: MLP, MSE {mse}')
# Out:
# clf: MLP, RMSE: 0.026538579066803344
# clf: MLP, MSE 0.0007042961788849726

# %%
score(mlp_regressor, X_val_sc, y_val_sc['tplh'], 'mlp_S_SKL', 'tplh', 'val')
# Out:
# {'r2': 0.9992768533307875,
#  'rmse': 0.026538579066803344,
#  'mse': 0.0007042961788849726}

# %%
# Testing
y_test_pred_sc = mlp_regressor.predict(Xte_sc)

# %%
# Testing R² score
mlp_regressor.score(Xte_sc, yte_sc['tplh'])
# Out:
# 0.9992752050002677

# %%
# Testing error
rmse = root_mean_squared_error(yte_sc['tplh'], y_test_pred_sc)
mse = mean_squared_error(yte_sc['tplh'], y_test_pred_sc)
print(f'clf: MLP, RMSE: {rmse}')
print(f'clf: MLP, MSE {mse}')
# Out:
# clf: MLP, RMSE: 0.02688546999249926
# clf: MLP, MSE 0.000722828496717578

# %%
score(mlp_regressor, Xte_sc, yte_sc['tplh'], 'mlp_S_SKL', 'tplh', 'test')
# Out:
# {'r2': 0.9992752050002677,
#  'rmse': 0.02688546999249926,
#  'mse': 0.000722828496717578}

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=y_pred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=y_val_sc['tplh'], label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -SKL Validation, TpLH')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=y_test_pred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=yte_sc['tplh'], label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -SKL Testing, TpLH')
ax.legend()
plt.show()

# %% [markdown]
# #### Predicting Energy

# %%
# Training
mlp_regressor.fit(X_train_sc, y_train_sc['iint'])
# Out:
# Iteration 1, loss = 0.15235138
# Validation score: 0.906408
# Iteration 2, loss = 0.02729838
# Validation score: 0.969404
# Iteration 3, loss = 0.01066843
# Validation score: 0.985047
# Iteration 4, loss = 0.00559104
# Validation score: 0.991362
# Iteration 5, loss = 0.00354643
# Validation score: 0.993767
# Iteration 6, loss = 0.00268264
# Validation score: 0.995150
# Iteration 7, loss = 0.00219327
# Validation score: 0.995740
# Iteration 8, loss = 0.00189123
# Validation score: 0.996357
# Iteration 9, loss = 0.00167856
# Validation score: 0.996766
# Iteration 10, loss = 0.00152684
# Validation score: 0.997037
# Iteration 11, loss = 0.00141017
# Validation score: 0.997164
# Iteration 12, loss = 0.00133038
# Validation score: 0.997285
# Iteration 13, loss = 0.00123796
# Validation score: 0.997593
# Iteration 14, loss = 0.00119708
# Validation score: 0.997565
# Iteration 15, loss = 0.00116758
# Validation score: 0.997792
# Iteration 16, loss = 0.00114618
# Validation score: 0.997817
# Iteration 17, loss = 0.00110628
# Validation score: 0.997757
# Iteration 18, loss = 0.00108165
# Validation score: 0.997854
# Iteration 19, loss = 0.00105873
# Validation score: 0.997918
# Iteration 20, loss = 0.00103189
# Validation score: 0.997984
# Iteration 21, loss = 0.00103086
# Validation score: 0.997944
# Iteration 22, loss = 0.00101675
# Validation score: 0.998007
# Iteration 23, loss = 0.00099009
# Validation score: 0.998004
# Iteration 24, loss = 0.00098554
# Validation score: 0.998106
# Iteration 25, loss = 0.00096289
# Validation score: 0.998091
# Iteration 26, loss = 0.00095239
# Validation score: 0.998102
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(early_stopping=True, max_iter=500, random_state=42, verbose=True)

# %%
print(mlp_regressor.out_activation_)
print(mlp_regressor.loss_)
# Out:
# identity
# 0.0009523914103849731

# %%
# Validation
y_pred_sc = mlp_regressor.predict(X_val_sc)

# %%
# Validation R² score
mlp_regressor.score(X_val_sc, y_val_sc['iint'])
# Out:
# 0.9980962556050871

# %%
# Validation error
rmse = root_mean_squared_error(y_val_sc['iint'], y_pred_sc)
mse = mean_squared_error(y_val_sc['iint'], y_pred_sc)
print(f'clf: MLP, RMSE: {rmse}')
print(f'clf: MLP, MSE {mse}')
# Out:
# clf: MLP, RMSE: 0.043603618442035995
# clf: MLP, MSE 0.0019012755412386618

# %%
score(mlp_regressor, X_val_sc, y_val_sc['iint'], 'mlp_S_SKL', 'corrent', 'val')
# Out:
# {'r2': 0.9980962556050871,
#  'rmse': 0.043603618442035995,
#  'mse': 0.0019012755412386618}

# %%
# Testing
y_test_pred_sc = mlp_regressor.predict(Xte_sc)

# %%
# Testing R² score
mlp_regressor.score(Xte_sc, yte_sc['iint'])
# Out:
# 0.9981114338162919

# %%
# Testing error
rmse = root_mean_squared_error(yte_sc['iint'], y_test_pred_sc)
mse = mean_squared_error(yte_sc['iint'], y_test_pred_sc)
print(f'clf: MLP, RMSE: {rmse}')
print(f'clf: MLP, MSE {mse}')
# Out:
# clf: MLP, RMSE: 0.043540876721331515
# clf: MLP, MSE 0.0018958079456621883

# %%
score(mlp_regressor, Xte_sc, yte_sc['iint'], 'mlp_S_SKL', 'corrent', 'test')
# Out:
# {'r2': 0.9981114338162919,
#  'rmse': 0.043540876721331515,
#  'mse': 0.0018958079456621883}

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=y_pred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=y_val_sc['iint'], label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -SKL Validation, Energy')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=y_test_pred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=yte_sc['iint'], label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -SKL Testing, Energy')
ax.legend()
plt.show()

# %% [markdown]
# ### Multi-output model

# %%
# Training
mlp_regressor.fit(X_train_sc, y_train_sc)
# Out:
# Iteration 1, loss = 0.16509695
# Validation score: 0.891659
# Iteration 2, loss = 0.03598445
# Validation score: 0.952214
# Iteration 3, loss = 0.01794609
# Validation score: 0.974305
# Iteration 4, loss = 0.01001788
# Validation score: 0.985005
# Iteration 5, loss = 0.00598511
# Validation score: 0.990544
# Iteration 6, loss = 0.00392209
# Validation score: 0.993423
# Iteration 7, loss = 0.00288223
# Validation score: 0.994818
# Iteration 8, loss = 0.00227964
# Validation score: 0.995760
# Iteration 9, loss = 0.00186894
# Validation score: 0.996574
# Iteration 10, loss = 0.00158069
# Validation score: 0.996974
# Iteration 11, loss = 0.00139297
# Validation score: 0.997365
# Iteration 12, loss = 0.00125835
# Validation score: 0.997611
# Iteration 13, loss = 0.00114812
# Validation score: 0.997773
# Iteration 14, loss = 0.00106569
# Validation score: 0.997974
# Iteration 15, loss = 0.00100220
# Validation score: 0.998054
# Iteration 16, loss = 0.00094876
# Validation score: 0.998132
# Iteration 17, loss = 0.00091445
# Validation score: 0.998176
# Iteration 18, loss = 0.00086752
# Validation score: 0.998308
# Iteration 19, loss = 0.00083707
# Validation score: 0.998360
# Iteration 20, loss = 0.00081226
# Validation score: 0.998354
# Iteration 21, loss = 0.00079681
# Validation score: 0.998430
# Iteration 22, loss = 0.00077505
# Validation score: 0.998472
# Iteration 23, loss = 0.00076157
# Validation score: 0.998481
# Iteration 24, loss = 0.00074360
# Validation score: 0.998446
# Iteration 25, loss = 0.00073342
# Validation score: 0.998504
# Iteration 26, loss = 0.00073037
# Validation score: 0.998542
# Iteration 27, loss = 0.00071941
# Validation score: 0.998510
# Iteration 28, loss = 0.00071772
# Validation score: 0.998562
# Iteration 29, loss = 0.00070014
# Validation score: 0.998582
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(early_stopping=True, max_iter=500, random_state=42, verbose=True)

# %%
print(mlp_regressor.out_activation_)
print(mlp_regressor.loss_)
# Out:
# identity
# 0.0007001388201414206

# %%
# Validation
y_pred_sc = mlp_regressor.predict(X_val_sc)

# %%
# Validation R² score
mlp_regressor.score(X_val_sc, y_val_sc)
# Out:
# 0.9985961682867185

# %%
# Validation error
rmse = root_mean_squared_error(y_val_sc, y_pred_sc)
mse = mean_squared_error(y_val_sc, y_pred_sc)
print(f'clf: MLP, RMSE: {rmse}')
print(f'clf: MLP, MSE {mse}')
# Out:
# clf: MLP, RMSE: 0.03595639518954292
# clf: MLP, MSE 0.0013953278831484101

# %%
score(mlp_regressor, X_val_sc, y_val_sc, 'mlp_M_SKL', 'all', 'val')
# Out:
# {'r2': 0.9985961682867185,
#  'rmse': 0.03595639518954292,
#  'mse': 0.0013953278831484101}

# %%
# Testing
y_test_pred_sc = mlp_regressor.predict(Xte_sc)

# %%
# Testing R² score
mlp_regressor.score(Xte_sc, yte_sc)
# Out:
# 0.9985881546348371

# %%
# Testing error
rmse = root_mean_squared_error(yte_sc, y_test_pred_sc)
mse = mean_squared_error(yte_sc, y_test_pred_sc)
print(f'clf: MLP, RMSE: {rmse}')
print(f'clf: MLP, MSE {mse}')
# Out:
# clf: MLP, RMSE: 0.0363835884256544
# clf: MLP, MSE 0.0014175790453814317

# %%
score(mlp_regressor, Xte_sc, yte_sc, 'mlp_M_SKL', 'all', 'test')
# Out:
# {'r2': 0.9985881546348371,
#  'rmse': 0.0363835884256544,
#  'mse': 0.0014175790453814317}

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=y_pred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=y_val_sc, label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -SKL Validation, All')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=y_test_pred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=yte_sc, label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -SKL Testing, All')
ax.legend()
plt.show()

# %% [markdown]
# ## Multi-layer Perceptron for Regression using Keras

# %% [markdown]
# Use test set and evaluate()

# %%
import tensorflow as tf
from tensorflow import keras

# %%
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    patience=15, 
    restore_best_weights=True
)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
# Out:
# E0000 00:00:1776565863.865433   66833 cuda_executor.cc:1737] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1776565863.865726   67001 cuda_executor.cc:1755] Failed to determine cuDNN version (Note that this is expected if the application doesn't link the cuDNN plugin): INTERNAL: cuDNN error: CUDNN_STATUS_INTERNAL_ERROR
# W0000 00:00:1776565863.887272   66833 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# ### Single-output models

# %%
model = tf.keras.models.Sequential([
    keras.layers.Dense(100, activation="relu", input_shape=X_train_sc.shape[1:]),
    keras.layers.Dense(50, activation='relu'),
    keras.layers.Dense(1)
])
# Out:
# /home/eduarda/jupyter_ic/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# #### Predicting TPHL

# %%
K.clear_session()
model.compile(loss="mean_squared_error", optimizer="adam")
history = model.fit(X_train_sc, y_train_sc['tphl'], epochs=500, batch_size=32, validation_data=(X_val_sc, y_val_sc['tphl']),
                    shuffle=True, callbacks=[early_stop])
# Out:
# Epoch 1/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 811us/step - loss: 0.0337 - val_loss: 0.0012
# Epoch 2/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 764us/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 3/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 766us/step - loss: 0.0010 - val_loss: 5.5746e-04
# Epoch 4/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 779us/step - loss: 7.7138e-04 - val_loss: 3.8814e-04
# Epoch 5/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 772us/step - loss: 7.5755e-04 - val_loss: 5.9364e-04
# Epoch 6/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 765us/step - loss: 5.7915e-04 - val_loss: 3.1254e-04
# Epoch 7/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 771us/step - loss: 5.1826e-04 - val_loss: 2.7344e-04
# Epoch 8/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 764us/step - loss: 5.4250e-04 - val_loss: 4.1502e-04
# Epoch 9/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 775us/step - loss: 4.3858e-04 - val_loss: 2.5405e-04
# Epoch 10/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 772us/step - loss: 4.2880e-04 - val_loss: 2.5454e-04
# Epoch 11/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 756us/step - loss: 4.2595e-04 - val_loss: 0.0012
# Epoch 12/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 764us/step - loss: 3.8407e-04 - val_loss: 2.1132e-04
# Epoch 13/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 842us/step - loss: 3.9098e-04 - val_loss: 2.3591e-04
# Epoch 14/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 822us/step - loss: 4.0719e-04 - val_loss: 2.9669e-04
# Epoch 15/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 827us/step - loss: 3.5604e-04 - val_loss: 2.3050e-04
# Epoch 16/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 787us/step - loss: 3.4541e-04 - val_loss: 4.5344e-04
# Epoch 17/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 791us/step - loss: 3.1636e-04 - val_loss: 2.2005e-04
# Epoch 18/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 800us/step - loss: 2.9868e-04 - val_loss: 3.9241e-04
# Epoch 19/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 779us/step - loss: 3.0501e-04 - val_loss: 2.6525e-04
# Epoch 20/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 786us/step - loss: 3.2465e-04 - val_loss: 2.0017e-04
# Epoch 21/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 811us/step - loss: 3.9342e-04 - val_loss: 2.8341e-04
# Epoch 22/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 801us/step - loss: 2.4895e-04 - val_loss: 1.7262e-04
# Epoch 23/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 885us/step - loss: 2.7207e-04 - val_loss: 1.7018e-04
# Epoch 24/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 825us/step - loss: 2.7616e-04 - val_loss: 2.5626e-04
# Epoch 25/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 811us/step - loss: 2.9038e-04 - val_loss: 1.5470e-04
# Epoch 26/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 805us/step - loss: 2.8019e-04 - val_loss: 1.4054e-04
# Epoch 27/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 826us/step - loss: 2.3647e-04 - val_loss: 2.3647e-04
# Epoch 28/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 804us/step - loss: 2.7522e-04 - val_loss: 2.9378e-04
# Epoch 29/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 807us/step - loss: 2.5189e-04 - val_loss: 1.7626e-04
# Epoch 30/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 815us/step - loss: 3.2621e-04 - val_loss: 3.5260e-04
# Epoch 31/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 822us/step - loss: 2.3409e-04 - val_loss: 1.6306e-04
# Epoch 32/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 827us/step - loss: 2.2891e-04 - val_loss: 1.7325e-04
# Epoch 33/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 801us/step - loss: 2.2997e-04 - val_loss: 7.3129e-04
# Epoch 34/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 810us/step - loss: 2.3690e-04 - val_loss: 9.8452e-05
# Epoch 35/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 833us/step - loss: 2.5632e-04 - val_loss: 1.5270e-04
# Epoch 36/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 819us/step - loss: 2.0726e-04 - val_loss: 3.8090e-04
# Epoch 37/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 838us/step - loss: 2.2978e-04 - val_loss: 1.1339e-04
# Epoch 38/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 834us/step - loss: 2.2334e-04 - val_loss: 1.5244e-04
# Epoch 39/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 827us/step - loss: 2.1536e-04 - val_loss: 1.5747e-04
# Epoch 40/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 887us/step - loss: 2.2580e-04 - val_loss: 1.2350e-04
# Epoch 41/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 840us/step - loss: 2.3328e-04 - val_loss: 5.3124e-04
# Epoch 42/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 801us/step - loss: 2.0544e-04 - val_loss: 3.7332e-04
# Epoch 43/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 808us/step - loss: 2.1170e-04 - val_loss: 1.4163e-04
# Epoch 44/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 869us/step - loss: 1.9057e-04 - val_loss: 1.2524e-04
# Epoch 45/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 822us/step - loss: 2.0556e-04 - val_loss: 1.6992e-04
# Epoch 46/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 855us/step - loss: 1.8438e-04 - val_loss: 1.5702e-04
# Epoch 47/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 829us/step - loss: 2.0163e-04 - val_loss: 2.0002e-04
# Epoch 48/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 804us/step - loss: 2.1754e-04 - val_loss: 2.1176e-04
# Epoch 49/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 844us/step - loss: 1.9295e-04 - val_loss: 2.8270e-04

# %%
ypred_sc = model.predict(X_val_sc)
mse = mean_squared_error(y_val_sc['tphl'], ypred_sc)
rmse = root_mean_squared_error(y_val_sc['tphl'], ypred_sc)
print(f'clf: ANN, rmse: {rmse}')
print(f'clf: ANN, mse: {mse}')
# Out:
# 989/989 ━━━━━━━━━━━━━━━━━━━━ 0s 345us/step
# clf: ANN, rmse: 0.009922302563012353
# clf: ANN, mse: 9.845208815196149e-05

# %%
r2 = r2_score(y_val_sc['tphl'], ypred_sc)
print(f'R²: {r2}')
# Out:
# R²: 0.9999018736547527

# %%
score(model, X_val_sc, y_val_sc['tphl'], 'mlp_S_K', 'tphl', 'val')
# Out:
# 989/989 ━━━━━━━━━━━━━━━━━━━━ 0s 347us/step
# {'r2': 0.9999018736547527,
#  'rmse': 0.009922302563012353,
#  'mse': 9.845208815196149e-05}

# %% [markdown]
# #### Predicting TPLH

# %%
K.clear_session()
model.compile(loss="mean_squared_error", optimizer="adam")
history = model.fit(X_train_sc, y_train_sc['tplh'], epochs=500, batch_size=32, validation_data=(X_val_sc, y_val_sc['tplh']),
                    shuffle=True, callbacks=[early_stop])
# Out:
# Epoch 1/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 892us/step - loss: 0.0455 - val_loss: 9.1672e-04
# Epoch 2/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 805us/step - loss: 9.5997e-04 - val_loss: 7.6274e-04
# Epoch 3/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 791us/step - loss: 9.4396e-04 - val_loss: 0.0018
# Epoch 4/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 885us/step - loss: 9.3178e-04 - val_loss: 0.0011
# Epoch 5/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 809us/step - loss: 9.1815e-04 - val_loss: 8.9509e-04
# Epoch 6/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 821us/step - loss: 9.0002e-04 - val_loss: 7.4501e-04
# Epoch 7/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 804us/step - loss: 8.6899e-04 - val_loss: 7.4029e-04
# Epoch 8/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 831us/step - loss: 8.5974e-04 - val_loss: 7.4392e-04
# Epoch 9/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 837us/step - loss: 8.3236e-04 - val_loss: 8.3570e-04
# Epoch 10/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 791us/step - loss: 8.2367e-04 - val_loss: 0.0014
# Epoch 11/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 847us/step - loss: 8.3213e-04 - val_loss: 7.5120e-04
# Epoch 12/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 784us/step - loss: 8.1983e-04 - val_loss: 6.7722e-04
# Epoch 13/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 868us/step - loss: 8.0608e-04 - val_loss: 7.2275e-04
# Epoch 14/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 806us/step - loss: 8.1147e-04 - val_loss: 7.8536e-04
# Epoch 15/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 816us/step - loss: 8.0305e-04 - val_loss: 7.7730e-04

# %%
ypred_sc = model.predict(X_val_sc)
mse = mean_squared_error(y_val_sc['tplh'], ypred_sc)
rmse = root_mean_squared_error(y_val_sc['tplh'], ypred_sc)
print(f'clf: ANN, rmse: {rmse}')
print(f'clf: ANN, mse: {mse}')
# Out:
# 989/989 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step
# clf: ANN, rmse: 0.03027735963117175
# clf: ANN, mse: 0.0009167185062353087

# %%
r2 = r2_score(y_val_sc['tplh'], ypred_sc)

print(f'R²: {r2}')
# Out:
# R²: 0.9990587455189107

# %%
score(model, X_val_sc, y_val_sc['tplh'], 'mlp_S_K', 'tplh', 'val')
# Out:
# 989/989 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step
# {'r2': 0.9990587455189107,
#  'rmse': 0.03027735963117175,
#  'mse': 0.0009167185062353087}

# %% [markdown]
# #### Predicting Energy

# %%
K.clear_session()
model.compile(loss="mean_squared_error", optimizer="adam")
history = model.fit(X_train_sc, y_train_sc['iint'], epochs=500, batch_size=32, validation_data=(X_val_sc, y_val_sc['iint']),
                    shuffle=True, callbacks=[early_stop])
# Out:
# Epoch 1/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 898us/step - loss: 0.0443 - val_loss: 0.0027
# Epoch 2/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 800us/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 3/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 817us/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 4/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 819us/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 5/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 801us/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 6/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 900us/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 7/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 938us/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 8/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 911us/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 9/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 898us/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 10/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 973us/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 11/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 908us/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 12/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 887us/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 13/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 930us/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 14/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 890us/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 15/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 827us/step - loss: 0.0017 - val_loss: 0.0015

# %%
ypred_sc = model.predict(X_val_sc)
mse = mean_squared_error(y_val_sc['iint'], ypred_sc)
rmse = root_mean_squared_error(y_val_sc['iint'], ypred_sc)
print(f'clf: ANN, rmse: {rmse}')
print(f'clf: ANN, mse: {mse}')
# Out:
# 989/989 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step
# clf: ANN, rmse: 0.05169922603740895
# clf: ANN, mse: 0.0026728099728671037

# %%
r2 = r2_score(y_val_sc['iint'], ypred_sc)
print(f'R²: {r2}')
# Out:
# R²: 0.9973237193167708

# %%
score(model, X_val_sc, y_val_sc['iint'], 'mlp_S_K', 'corrent', 'val')
# Out:
# 989/989 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step
# {'r2': 0.9973237193167708,
#  'rmse': 0.05169922603740895,
#  'mse': 0.0026728099728671037}

# %% [markdown]
# ### Multi-output model

# %%
model = tf.keras.models.Sequential([
    keras.layers.Dense(100, activation="relu", input_shape=X_train_sc.shape[1:]),
    keras.layers.Dense(50, activation='relu'),
    keras.layers.Dense(3)
])

K.clear_session()
model.compile(loss="mean_squared_error", optimizer="adam")
history = model.fit(X_train_sc, y_train_sc, epochs=500, batch_size=32, validation_data=(X_val_sc, y_val_sc), 
                    shuffle=True, callbacks=[early_stop])
# Out:
# /home/eduarda/jupyter_ic/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 871us/step - loss: 0.0404 - val_loss: 0.0030
# Epoch 2/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 807us/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 3/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 861us/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 4/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 803us/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 5/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 789us/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 6/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 830us/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 7/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 809us/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 8/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 852us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 9/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 853us/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 10/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 829us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 11/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 830us/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 12/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 833us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 13/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 816us/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 14/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 816us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 15/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 812us/step - loss: 0.0012 - val_loss: 0.0012

# %%
ypred_sc = model.predict(X_val_sc)
mse = mean_squared_error(y_val_sc, ypred_sc)
rmse = root_mean_squared_error(y_val_sc, ypred_sc)
print(f'clf: ANN, rmse: {rmse}')
print(f'clf: ANN, mse: {mse}')
# Out:
# 989/989 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step
# clf: ANN, rmse: 0.053731393069028854
# clf: ANN, mse: 0.0030033241491764784

# %%
r2 = r2_score(y_val_sc, ypred_sc)

print(f'R²: {r2}')
# Out:
# R²: 0.9969792366027832

# %%
score(model, X_val_sc, y_val_sc, 'mlp_M_K', 'all', 'val')
# Out:
# 989/989 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step
# {'r2': 0.9969792366027832,
#  'rmse': 0.053731393069028854,
#  'mse': 0.0030033241491764784}

# %% [markdown]
# ## Results

# %%
import os

results = pd.DataFrame.from_dict(scores, orient='index')

path = os.path.join('../outputs/not_32nm_cmos', 'results_mlps')

results.to_csv(path, index_label='target_name')
print(results)
# Out:
#                               r2      rmse       mse
# mlp_S_SKL tphl    val   0.999656  0.018585  0.000345
#                   test  0.999643  0.019030  0.000362
#           tplh    val   0.999277  0.026539  0.000704
#                   test  0.999275  0.026885  0.000723
#           corrent val   0.998096  0.043604  0.001901
#                   test  0.998111  0.043541  0.001896
# mlp_M_SKL all     val   0.998596  0.035956  0.001395
#                   test  0.998588  0.036384  0.001418
# mlp_S_K   tphl    val   0.999902  0.009922  0.000098
#           tplh    val   0.999059  0.030277  0.000917
#           corrent val   0.997324  0.051699  0.002673
# mlp_M_K   all     val   0.996979  0.053731  0.003003
