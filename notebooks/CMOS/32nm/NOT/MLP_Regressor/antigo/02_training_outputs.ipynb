# %% [markdown]
# INVERTER 32nm CMOS data

# %%
import pandas as pd
import joblib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import tensorflow as tf
import numpy as np
import os
from tensorflow.keras import backend as K
from sklearn.metrics import root_mean_squared_error, mean_squared_error, r2_score
from sklearn.neural_network import MLPRegressor
from joblib import load

K.clear_session()

plots_dir = "../../../../../figures/CMOS/32nm/NOT/02_training_outputs/"

# Loading scalers
scaler_x = joblib.load('../../../../../data/processed/CMOS/32nm/NOT/scaler_x.pkl')
scaler_y = joblib.load('../../../../../data/processed/CMOS/32nm/NOT/scaler_y.pkl')

# Loading split data

X_train_sc = pd.read_csv('../../../../../data/processed/CMOS/32nm/NOT/X_train_sc.csv')
X_val_sc   = pd.read_csv('../../../../../data/processed/CMOS/32nm/NOT/X_val_sc.csv')
Xte_sc     = pd.read_csv('../../../../../data/processed/CMOS/32nm/NOT/X_test_sc.csv')

y_train_sc = pd.read_csv('../../../../../data/processed/CMOS/32nm/NOT/y_train_sc.csv')
y_val_sc   = pd.read_csv('../../../../../data/processed/CMOS/32nm/NOT/y_val_sc.csv')
yte_sc     = pd.read_csv('../../../../../data/processed/CMOS/32nm/NOT/y_test_sc.csv')

print(f"Training set loaded: {X_train_sc.shape}")
print(f"Validation set loaded: {X_val_sc.shape}")
print(f"Test set loaded: {Xte_sc.shape}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779987064.037095   19771 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1779987064.037585   19771 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1779987064.080788   19771 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779987065.300529   19771 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1779987065.300874   19771 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# Training set loaded: (64204, 7)
# Validation set loaded: (31624, 7)
# Test set loaded: (31943, 7)

# %% [markdown]
# ### Plot Functions

# %%
variables = ['TPHL', 'TPLH', 'CORRENT']

plt.rcParams.update({
    "font.family": "serif",
    "font.size": 12,
    "axes.labelsize": 14,
    "axes.titlesize": 14,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "legend.fontsize": 12
})

def scatter_plot_multi_output_regression_results(y_predi, y_real, target_names, fname, subtitle=None):
    y_pred = np.array(y_predi)
    y_true = np.array(y_real)
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    if subtitle:
        fig.suptitle(subtitle, fontsize=13, fontweight='bold', y=1.02)
    
    for i in range(3):
        ax = axes[i]
        
        sns.scatterplot(x=y_true[:, i], y=y_pred[:, i], ax=ax, 
                        alpha=0.5, color='royalblue', edgecolor=None)
        
        low = min(y_true[:, i].min(), y_pred[:, i].min())
        high = max(y_true[:, i].max(), y_pred[:, i].max())
        ax.plot([low, high], [low, high], color='red', linestyle='--', lw=2, label='Ideal')
        

        r2 = r2_score(y_true[:, i], y_pred[:, i])
        rmse = np.sqrt(mean_squared_error(y_true[:, i], y_pred[:, i]))
        
        ax.set_title(f'{target_names[i]}\n$R^2 = {r2:.3f}$ | $RMSE = {rmse:.3f}$')
        ax.set_xlabel('Valores Reais ($y_{true}$)')
        ax.set_ylabel(r'Predições ($\hat{y}$)')
        ax.grid(True, linestyle=':', alpha=0.6)
        if i == 0: ax.legend()

    plt.tight_layout()
    plt.savefig(f"{plots_dir}{fname}.png", dpi=300, bbox_inches='tight') 
    plt.show()

def kde_plot_multi_output_regression_results(y_pred, y_real, target_names, fname, subtitle=None):
    y_pred_np = np.array(y_pred)
    y_val_np  = np.array(y_real)

    for i, var in enumerate(target_names):
        fig, ax = plt.subplots(1, 1, figsize=(10, 7))

        sns.kdeplot(data=y_pred_np[:, i], label='predicted', ax=ax, color='royalblue')
        sns.kdeplot(data=y_val_np[:, i],  label='true',      ax=ax, color='red')

        title = f'{subtitle}, {var}' if subtitle else var
        ax.set_title(title)
        ax.legend()

        plt.savefig(f"{plots_dir}/{fname}_{var}.png")
        plt.show()
        plt.close()

# %% [markdown]
# # Multi-layer Perceptron (MPL)
# Neural network for supervised learning
#
# Idea:
# - Single-output model approach (Predicting one output at a time)
# - Multi-output model approach (Predicting three outputs at the same time)

# %% [markdown]
# Metrics
# - R² score (coefficient of determination) regression score function
# - RMSE and MSE error metrics

# %%
scores = {}

# %%
def score(model, X, y, target_name, target_variable, target_set):
    pred = model.predict(X)
    r2 = r2_score(y, pred)
    rmse = root_mean_squared_error(y, pred)
    mse = mean_squared_error(y, pred)

    scores[target_name, target_variable, target_set] = {
        'r2': r2,
        'rmse': rmse,
        'mse': mse,
    }
    return scores[target_name, target_variable, target_set]

# %% [markdown]
# ## Multi-layer Perceptron for Regression using Scikit-Learn

# %%
mlp_regressor= MLPRegressor(activation='relu',
                            solver = 'adam',
                            max_iter=500,
                            shuffle=True,
                            validation_fraction=0.1,
                            n_iter_no_change=10,
                            hidden_layer_sizes=(100, ),
                            early_stopping = True,
                            random_state=42,
                            verbose=True
                           )

# %% [markdown]
# - input neurons: 7 neurons (7 input variables)
# - hidden layers: default 100 neurons in hidden layer
# - neurons per hidden layes: 1 neuron (single-output model)
# - hidden activation: relu
# - output activation: relu?
# - loss function: default squared_error
#
# - activation function for hidden layer: 'relu', the rectified linear unit function, returns f(x) = max(0, x)
# - solver: 'adam' refers to a stochastic gradient-based optimizer
# - max_iter: 500
# - shuffle: true
# - validation_fraction: 0.1
# - n_iter_no_change: 10
# - hidden layer_sizes: 100
# - early_stopping: true
# - random_state: 42
# - verbose: true
#
# - learning_rate: default=’constant’
# 'constant' is a constant learning rate given by ‘learning_rate_init’
# learning_rate_init float, default=0.001

# %%
joblib.dump(mlp_regressor, "/home/eduarda/Repos/jupyter_ic/models/mlp_regressor_SKL_untrained.joblib")
# Out:
# ['/home/eduarda/Repos/jupyter_ic/models/mlp_regressor_SKL_untrained.joblib']

# %% [markdown]
# ### Single-output models

# %%
#### Predicting TPHL

# %%
# Training
mlp_regressor.fit(X_train_sc, y_train_sc['tphl'])
# Out:
# Iteration 1, loss = 0.13839182
# Validation score: 0.925934
# Iteration 2, loss = 0.02148583
# Validation score: 0.973076
# Iteration 3, loss = 0.00898416
# Validation score: 0.988601
# Iteration 4, loss = 0.00369022
# Validation score: 0.994741
# Iteration 5, loss = 0.00209567
# Validation score: 0.996627
# Iteration 6, loss = 0.00147060
# Validation score: 0.997264
# Iteration 7, loss = 0.00112573
# Validation score: 0.998109
# Iteration 8, loss = 0.00088707
# Validation score: 0.998481
# Iteration 9, loss = 0.00072745
# Validation score: 0.998747
# Iteration 10, loss = 0.00060615
# Validation score: 0.998929
# Iteration 11, loss = 0.00051324
# Validation score: 0.999098
# Iteration 12, loss = 0.00044589
# Validation score: 0.999250
# Iteration 13, loss = 0.00039501
# Validation score: 0.999224
# Iteration 14, loss = 0.00036109
# Validation score: 0.999381
# Iteration 15, loss = 0.00032303
# Validation score: 0.999411
# Iteration 16, loss = 0.00029015
# Validation score: 0.999487
# Iteration 17, loss = 0.00027094
# Validation score: 0.999504
# Iteration 18, loss = 0.00025656
# Validation score: 0.999498
# Iteration 19, loss = 0.00025146
# Validation score: 0.999546
# Iteration 20, loss = 0.00023204
# Validation score: 0.999554
# Iteration 21, loss = 0.00022558
# Validation score: 0.999543
# Iteration 22, loss = 0.00021479
# Validation score: 0.999632
# Iteration 23, loss = 0.00020932
# Validation score: 0.999641
# Iteration 24, loss = 0.00019441
# Validation score: 0.999659
# Iteration 25, loss = 0.00018926
# Validation score: 0.999620
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(early_stopping=True, max_iter=500, random_state=42, verbose=True)

# %%
print(f"Output activation function: {mlp_regressor.out_activation_}")
print(f"The current loss computed with the loss function: {mlp_regressor.loss_}")
print(f"The minimum loss reached by the solver throughout fitting: {mlp_regressor.best_loss_}")
print(f"The number of iterations the solver has run: {mlp_regressor.n_iter_}")
print(f"Best R2 score that triggered early_stopping: {mlp_regressor.best_validation_score_}")
print(f"R2 score: {mlp_regressor.validation_scores_}")
print(f"Number of layers: {mlp_regressor.n_outputs_}")
print(f"Number of layers: {mlp_regressor.n_layers_}")
print(f"Number of features seen during fit: {mlp_regressor.n_features_in_}")
# Out:
# identity
# 0.00018926437785591515
# 1

# %%
# Validation
y_pred_sc = mlp_regressor.predict(X_val_sc)

# %%
# Validation R² score
mlp_regressor.score(X_val_sc, y_val_sc['tphl'])
# Out:
# 0.9996754255715159

# %%
# Validation error
rmse = root_mean_squared_error(y_val_sc['tphl'], y_pred_sc)
mse = mean_squared_error(y_val_sc['tphl'], y_pred_sc)
print(f'clf: MLP, RMSE: {rmse}')
print(f'clf: MLP, MSE {mse}')
# Out:
# clf: MLP, RMSE: 0.01804582762444334
# clf: MLP, MSE 0.00032565189465112243

# %%
score(mlp_regressor, X_val_sc, y_val_sc['tphl'], 'mlp_S_SKL', 'tphl', 'val')
# Out:
# {'r2': 0.9996754255715159,
#  'rmse': 0.01804582762444334,
#  'mse': 0.00032565189465112243}

# %%
# Testing
y_test_pred_sc = mlp_regressor.predict(Xte_sc)

# %%
# Testing R² score
mlp_regressor.score(Xte_sc, yte_sc['tphl'])
# Out:
# 0.9996568242502238

# %%
# Testing error
rmse = root_mean_squared_error(yte_sc['tphl'], y_test_pred_sc)
mse = mean_squared_error(yte_sc['tphl'], y_test_pred_sc)
print(f'clf: MLP, RMSE: {rmse}')
print(f'clf: MLP, MSE {mse}')
# Out:
# clf: MLP, RMSE: 0.01864515971001046
# clf: MLP, MSE 0.00034764198061179737

# %%
score(mlp_regressor, Xte_sc, yte_sc['tphl'], 'mlp_S_SKL', 'tphl', 'test')
# Out:
# {'r2': 0.9996568242502238,
#  'rmse': 0.01864515971001046,
#  'mse': 0.00034764198061179737}

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=y_pred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=y_val_sc['tphl'], label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -SKL Validation, TpHL')
ax.legend()
plt.savefig(f"{plots_dir}/MLP_S_SKL_VAL_TPHL.png")
plt.show()
plt.close()

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=y_test_pred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=yte_sc['tphl'], label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -SKL Testing, TpHL')
ax.legend()
plt.savefig(f"{plots_dir}/MLP_S_SKL_TEST_TPHL.png")
plt.show()
plt.close()

# %% [markdown]
# #### Predicting TPLH

# %%
# Training
mlp_regressor.fit(X_train_sc, y_train_sc['tplh'])
# Out:
# Iteration 1, loss = 0.14586533
# Validation score: 0.890270
# Iteration 2, loss = 0.03406379
# Validation score: 0.964349
# Iteration 3, loss = 0.01156348
# Validation score: 0.986576
# Iteration 4, loss = 0.00463336
# Validation score: 0.993774
# Iteration 5, loss = 0.00241561
# Validation score: 0.996269
# Iteration 6, loss = 0.00154544
# Validation score: 0.997399
# Iteration 7, loss = 0.00108161
# Validation score: 0.998058
# Iteration 8, loss = 0.00082937
# Validation score: 0.998508
# Iteration 9, loss = 0.00065984
# Validation score: 0.998835
# Iteration 10, loss = 0.00056786
# Validation score: 0.998925
# Iteration 11, loss = 0.00051212
# Validation score: 0.999027
# Iteration 12, loss = 0.00047634
# Validation score: 0.999073
# Iteration 13, loss = 0.00045176
# Validation score: 0.999143
# Iteration 14, loss = 0.00042509
# Validation score: 0.999212
# Iteration 15, loss = 0.00041082
# Validation score: 0.999183
# Iteration 16, loss = 0.00040025
# Validation score: 0.999235
# Iteration 17, loss = 0.00039185
# Validation score: 0.999271
# Iteration 18, loss = 0.00038660
# Validation score: 0.999272
# Iteration 19, loss = 0.00038202
# Validation score: 0.999228
# Iteration 20, loss = 0.00037309
# Validation score: 0.999220
# Iteration 21, loss = 0.00036640
# Validation score: 0.999287
# Iteration 22, loss = 0.00036639
# Validation score: 0.999287
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(early_stopping=True, max_iter=500, random_state=42, verbose=True)

# %%
print(mlp_regressor.out_activation_)
print(mlp_regressor.loss_)
# Out:
# identity
# 0.0003663888587580963

# %%
# Validation
y_pred_sc = mlp_regressor.predict(X_val_sc)

# %%
# Validation R² score
mlp_regressor.score(X_val_sc, y_val_sc['tplh'])
# Out:
# 0.9992730086252184

# %%
# Validation error
rmse = root_mean_squared_error(y_val_sc['tplh'], y_pred_sc)
mse = mean_squared_error(y_val_sc['tplh'], y_pred_sc)
print(f'clf: MLP, RMSE: {rmse}')
print(f'clf: MLP, MSE {mse}')
# Out:
# clf: MLP, RMSE: 0.026609033490751256
# clf: MLP, MSE 0.000708040663311922

# %%
score(mlp_regressor, X_val_sc, y_val_sc['tplh'], 'mlp_S_SKL', 'tplh', 'val')
# Out:
# {'r2': 0.9992730086252184,
#  'rmse': 0.026609033490751256,
#  'mse': 0.000708040663311922}

# %%
# Testing
y_test_pred_sc = mlp_regressor.predict(Xte_sc)

# %%
# Testing R² score
mlp_regressor.score(Xte_sc, yte_sc['tplh'])
# Out:
# 0.9992687983939565

# %%
# Testing error
rmse = root_mean_squared_error(yte_sc['tplh'], y_test_pred_sc)
mse = mean_squared_error(yte_sc['tplh'], y_test_pred_sc)
print(f'clf: MLP, RMSE: {rmse}')
print(f'clf: MLP, MSE {mse}')
# Out:
# clf: MLP, RMSE: 0.027004031564189256
# clf: MLP, MSE 0.0007292177207197297

# %%
score(mlp_regressor, Xte_sc, yte_sc['tplh'], 'mlp_S_SKL', 'tplh', 'test')
# Out:
# {'r2': 0.9992687983939565,
#  'rmse': 0.027004031564189256,
#  'mse': 0.0007292177207197297}

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=y_pred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=y_val_sc['tplh'], label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -SKL Validation, TpLH')
ax.legend()
plt.savefig(f"{plots_dir}/MLP_S_SKL_VAL_TPLH.png")
plt.show()
plt.close()

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=y_test_pred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=yte_sc['tplh'], label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -SKL Testing, TpLH')
plt.savefig(f"{plots_dir}/MLP_S_SKL_TEST_TPLH.png")
ax.legend()
plt.show()
plt.close()

# %% [markdown]
# #### Predicting Energy

# %%
# Training
mlp_regressor.fit(X_train_sc, y_train_sc['energy'])
# Out:
# Iteration 1, loss = 0.15574496
# Validation score: 0.909373
# Iteration 2, loss = 0.02574304
# Validation score: 0.970900
# Iteration 3, loss = 0.01003726
# Validation score: 0.986049
# Iteration 4, loss = 0.00533191
# Validation score: 0.991537
# Iteration 5, loss = 0.00349082
# Validation score: 0.993865
# Iteration 6, loss = 0.00265745
# Validation score: 0.995183
# Iteration 7, loss = 0.00221234
# Validation score: 0.995676
# Iteration 8, loss = 0.00192883
# Validation score: 0.996361
# Iteration 9, loss = 0.00171626
# Validation score: 0.996768
# Iteration 10, loss = 0.00155594
# Validation score: 0.997048
# Iteration 11, loss = 0.00144120
# Validation score: 0.997187
# Iteration 12, loss = 0.00135277
# Validation score: 0.997332
# Iteration 13, loss = 0.00126910
# Validation score: 0.997544
# Iteration 14, loss = 0.00121644
# Validation score: 0.997616
# Iteration 15, loss = 0.00117698
# Validation score: 0.997791
# Iteration 16, loss = 0.00114930
# Validation score: 0.997846
# Iteration 17, loss = 0.00109807
# Validation score: 0.997725
# Iteration 18, loss = 0.00106228
# Validation score: 0.997933
# Iteration 19, loss = 0.00102926
# Validation score: 0.998030
# Iteration 20, loss = 0.00100863
# Validation score: 0.998035
# Iteration 21, loss = 0.00099619
# Validation score: 0.997939
# Iteration 22, loss = 0.00098853
# Validation score: 0.998014
# Iteration 23, loss = 0.00096312
# Validation score: 0.998056
# Iteration 24, loss = 0.00095812
# Validation score: 0.998068
# Iteration 25, loss = 0.00093785
# Validation score: 0.998140
# Iteration 26, loss = 0.00093477
# Validation score: 0.998193
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(early_stopping=True, max_iter=500, random_state=42, verbose=True)

# %%
print(mlp_regressor.out_activation_)
print(mlp_regressor.loss_)
# Out:
# identity
# 0.0009347708717357159

# %%
# Validation
y_pred_sc = mlp_regressor.predict(X_val_sc)

# %%
# Validation R² score
mlp_regressor.score(X_val_sc, y_val_sc['energy'])
# Out:
# 0.9981770230257411

# %%
# Validation error
rmse = root_mean_squared_error(y_val_sc['energy'], y_pred_sc)
mse = mean_squared_error(y_val_sc['energy'], y_pred_sc)
print(f'clf: MLP, RMSE: {rmse}')
print(f'clf: MLP, MSE {mse}')
# Out:
# clf: MLP, RMSE: 0.042668640276935066
# clf: MLP, MSE 0.0018206128630824856

# %%
score(mlp_regressor, X_val_sc, y_val_sc['energy'], 'mlp_S_SKL', 'corrent', 'val')
# Out:
# {'r2': 0.9981770230257411,
#  'rmse': 0.042668640276935066,
#  'mse': 0.0018206128630824856}

# %%
# Testing
y_test_pred_sc = mlp_regressor.predict(Xte_sc)

# %%
# Testing R² score
mlp_regressor.score(Xte_sc, yte_sc['energy'])
# Out:
# 0.9981936869983989

# %%
# Testing error
rmse = root_mean_squared_error(yte_sc['energy'], y_test_pred_sc)
mse = mean_squared_error(yte_sc['energy'], y_test_pred_sc)
print(f'clf: MLP, RMSE: {rmse}')
print(f'clf: MLP, MSE {mse}')
# Out:
# clf: MLP, RMSE: 0.04258214838798361
# clf: MLP, MSE 0.0018132393613362553

# %%
score(mlp_regressor, Xte_sc, yte_sc['energy'], 'mlp_S_SKL', 'corrent', 'test')
# Out:
# {'r2': 0.9981936869983989,
#  'rmse': 0.04258214838798361,
#  'mse': 0.0018132393613362553}

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=y_test_pred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=yte_sc['energy'], label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -SKL Validation, Corrent')
plt.savefig(f"{plots_dir}/MLP_S_SKL_VAL_CORRENT.png")
ax.legend()
plt.show()
plt.close()

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=y_pred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=y_val_sc['energy'], label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -SKL Test, Corrent')
plt.savefig(f"{plots_dir}/MLP_S_SKL_TEST_CORRENT.png")
ax.legend()
plt.show()
plt.close()

# %% [markdown]
# ### Multi-output model

# %% [markdown]
# - input neurons: 7 neurons (7 input variables)
# - hidden layers: default 100 neurons in hidden layer
# - neurons per hidden layes: 3 neurons (single-output model)
# - hidden activation: relu
# - output activation: relu?
# - loss function: default squared_error
#
# - activation function for hidden layer: 'relu', the rectified linear unit function, returns f(x) = max(0, x)
# - solver: 'adam' refers to a stochastic gradient-based optimizer
# - max_iter: 500
# - shuffle:
# - validation_fraction:
# - n_iter_no_change:
# - hidden layer_sizes:
# - early_stopping:
# - random_state:
# - verbose:
#
# - learning_rate:

# %%
# Training
mlp_regressor.fit(X_train_sc, y_train_sc)
# Out:
# Iteration 1, loss = 0.16712254
# Validation score: 0.894033
# Iteration 2, loss = 0.03613796
# Validation score: 0.951400
# Iteration 3, loss = 0.01721455
# Validation score: 0.976770
# Iteration 4, loss = 0.00868187
# Validation score: 0.987277
# Iteration 5, loss = 0.00502736
# Validation score: 0.991907
# Iteration 6, loss = 0.00338936
# Validation score: 0.994241
# Iteration 7, loss = 0.00250339
# Validation score: 0.995484
# Iteration 8, loss = 0.00200626
# Validation score: 0.996195
# Iteration 9, loss = 0.00168647
# Validation score: 0.996847
# Iteration 10, loss = 0.00145574
# Validation score: 0.997211
# Iteration 11, loss = 0.00129468
# Validation score: 0.997545
# Iteration 12, loss = 0.00117280
# Validation score: 0.997764
# Iteration 13, loss = 0.00108553
# Validation score: 0.997895
# Iteration 14, loss = 0.00101712
# Validation score: 0.998084
# Iteration 15, loss = 0.00095002
# Validation score: 0.998195
# Iteration 16, loss = 0.00089404
# Validation score: 0.998253
# Iteration 17, loss = 0.00085818
# Validation score: 0.998288
# Iteration 18, loss = 0.00083024
# Validation score: 0.998362
# Iteration 19, loss = 0.00080298
# Validation score: 0.998421
# Iteration 20, loss = 0.00078129
# Validation score: 0.998461
# Iteration 21, loss = 0.00076766
# Validation score: 0.998476
# Iteration 22, loss = 0.00074628
# Validation score: 0.998487
# Iteration 23, loss = 0.00073486
# Validation score: 0.998558
# Iteration 24, loss = 0.00071848
# Validation score: 0.998585
# Iteration 25, loss = 0.00071254
# Validation score: 0.998568
# Iteration 26, loss = 0.00069953
# Validation score: 0.998607
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(early_stopping=True, max_iter=500, random_state=42, verbose=True)

# %%
print(mlp_regressor.out_activation_)
print(mlp_regressor.loss_)
print(mlp_regressor.n_outputs_)
# Out:
# identity
# 0.0006995285373070134

# %%
# Validation
y_pred_sc = mlp_regressor.predict(X_val_sc)

# %%
# Validation R² score
mlp_regressor.score(X_val_sc, y_val_sc)
# Out:
# 0.9986436370559426

# %%
# Validation error
rmse = root_mean_squared_error(y_val_sc, y_pred_sc)
mse = mean_squared_error(y_val_sc, y_pred_sc)
print(f'clf: MLP, RMSE: {rmse}')
print(f'clf: MLP, MSE {mse}')
# Out:
# clf: MLP, RMSE: 0.03502012522018573
# clf: MLP, MSE 0.001348017280905507

# %%
score(mlp_regressor, X_val_sc, y_val_sc, 'mlp_M_SKL', 'all', 'val')
# Out:
# {'r2': 0.9986436370559426,
#  'rmse': 0.03502012522018573,
#  'mse': 0.001348017280905507}

# %%
# Testing
y_test_pred_sc = mlp_regressor.predict(Xte_sc)

# %%
# Testing R² score
mlp_regressor.score(Xte_sc, yte_sc)
# Out:
# 0.9986319413767003

# %%
# Testing error
rmse = root_mean_squared_error(yte_sc, y_test_pred_sc)
mse = mean_squared_error(yte_sc, y_test_pred_sc)
print(f'clf: MLP, RMSE: {rmse}')
print(f'clf: MLP, MSE {mse}')
# Out:
# clf: MLP, RMSE: 0.0354252556631117
# clf: MLP, MSE 0.0013732150212694774

# %%
score(mlp_regressor, Xte_sc, yte_sc, 'mlp_M_SKL', 'all', 'test')
# Out:
# {'r2': 0.9986319413767003,
#  'rmse': 0.0354252556631117,
#  'mse': 0.0013732150212694774}

# %%
#scatter_plot_multi_output_regression_results(y_pred_sc, y_val_sc, variables, "MLP_M_SKL_VAL_ALL_SCATTER", "MLP_M_SKL_VAL_ALL_SCATTER")

# %%
kde_plot_multi_output_regression_results(y_pred_sc, y_val_sc, variables, "MLP_M_SKL_VAL_ALL", "MLP_M_SKL_VAL_ALL")

# %%
# scatter_plot_multi_output_regression_results(y_test_pred_sc, yte_sc, variables, "MLP_M_SKL_TEST_ALL_SCATTER", "MLP_M_SKL_TEST_ALL_SCATTER")

# %%
kde_plot_multi_output_regression_results(y_test_pred_sc, yte_sc, variables, "MLP_M_SKL_TEST_ALL", "MLP_M_SKL_TEST_ALL")

# %% [markdown]
# ## Multi-layer Perceptron for Regression using Keras

# %% [markdown]
# Use test set and evaluate()

# %%
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    patience=15, 
    restore_best_weights=True
)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
# Out:
# E0000 00:00:1779987087.082874   19771 cuda_executor.cc:1737] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1779987087.083468   19961 cuda_executor.cc:1755] Failed to determine cuDNN version (Note that this is expected if the application doesn't link the cuDNN plugin): INTERNAL: cuDNN error: CUDNN_STATUS_INTERNAL_ERROR
# W0000 00:00:1779987087.109218   19771 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# ### Single-output models

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(100, activation="relu", input_shape=X_train_sc.shape[1:]),
    tf.keras.layers.Dense(50, activation='relu'),
    tf.keras.layers.Dense(1)
])
# Out:
# /home/eduarda/Repos/jupyter_ic/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# print(model.outputs)

# %% [markdown]
# - input neurons:
# - hidden layers:
# - neurons per hidden layes:
# - hidden activation:
# - output activation:
# - loss function:
#
# - activation function for hidden layer:
# - solver:
# - max_iter:
# - shuffle:
# - validation_fraction:
# - n_iter_no_change:
# - hidden layer_sizes:
# - early_stopping:
# - random_state:
# - verbose:
#
# - learning_rate

# %% [markdown]
# #### Predicting TPHL

# %%
K.clear_session()
model.compile(loss="mean_squared_error", optimizer="adam")
history = model.fit(X_train_sc, y_train_sc['tphl'], epochs=500, batch_size=32, validation_data=(X_val_sc, y_val_sc['tphl']),
                    shuffle=True, callbacks=[early_stop])
# Out:
# Epoch 1/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0316 - val_loss: 0.0011
# Epoch 2/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 3/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.7973e-04 - val_loss: 8.8607e-04
# Epoch 4/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 7.6829e-04 - val_loss: 0.0015
# Epoch 5/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 6.8077e-04 - val_loss: 5.1805e-04
# Epoch 6/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 6.1124e-04 - val_loss: 5.9294e-04
# Epoch 7/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 5.2139e-04 - val_loss: 2.4175e-04
# Epoch 8/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.9402e-04 - val_loss: 4.3668e-04
# Epoch 9/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 5.5027e-04 - val_loss: 5.1345e-04
# Epoch 10/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.5109e-04 - val_loss: 8.0834e-04
# Epoch 11/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.4878e-04 - val_loss: 4.1380e-04
# Epoch 12/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.5050e-04 - val_loss: 4.5320e-04
# Epoch 13/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 4.1235e-04 - val_loss: 1.9385e-04
# Epoch 14/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 3.3742e-04 - val_loss: 2.5749e-04
# Epoch 15/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 3.7851e-04 - val_loss: 2.6802e-04
# Epoch 16/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 3.4620e-04 - val_loss: 2.9139e-04
# Epoch 17/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 3.4219e-04 - val_loss: 4.1767e-04
# Epoch 18/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 3.4068e-04 - val_loss: 1.8058e-04
# Epoch 19/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.9528e-04 - val_loss: 1.3560e-04
# Epoch 20/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 3.5745e-04 - val_loss: 7.5056e-04
# Epoch 21/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 3.0090e-04 - val_loss: 5.9361e-04
# Epoch 22/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 3.1297e-04 - val_loss: 4.9024e-04
# Epoch 23/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.5953e-04 - val_loss: 0.0013
# Epoch 24/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.8634e-04 - val_loss: 1.7347e-04
# Epoch 25/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.7048e-04 - val_loss: 1.8536e-04
# Epoch 26/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 2.8194e-04 - val_loss: 6.6381e-04
# Epoch 27/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.6652e-04 - val_loss: 4.1128e-04
# Epoch 28/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.5034e-04 - val_loss: 3.3952e-04
# Epoch 29/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.5348e-04 - val_loss: 2.1809e-04
# Epoch 30/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.4415e-04 - val_loss: 4.2250e-04
# Epoch 31/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 2.4191e-04 - val_loss: 9.5643e-05
# Epoch 32/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 2.2542e-04 - val_loss: 1.7070e-04
# Epoch 33/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 2.5038e-04 - val_loss: 0.0022
# Epoch 34/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 2.3153e-04 - val_loss: 2.9363e-04
# Epoch 35/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 2.1270e-04 - val_loss: 1.6353e-04
# Epoch 36/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 2.2960e-04 - val_loss: 1.1208e-04
# Epoch 37/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.1254e-04 - val_loss: 1.6049e-04
# Epoch 38/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.0394e-04 - val_loss: 5.6942e-04
# Epoch 39/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.1639e-04 - val_loss: 3.3416e-04
# Epoch 40/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.2263e-04 - val_loss: 1.6826e-04
# Epoch 41/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.8581e-04 - val_loss: 1.1219e-04
# Epoch 42/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.0420e-04 - val_loss: 1.0889e-04
# Epoch 43/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.8162e-04 - val_loss: 1.4898e-04
# Epoch 44/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.9525e-04 - val_loss: 1.0362e-04
# Epoch 45/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.1054e-04 - val_loss: 1.5813e-04
# Epoch 46/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.8354e-04 - val_loss: 1.3329e-04

# %%
ypred_sc = model.predict(X_val_sc)
mse = mean_squared_error(y_val_sc['tphl'], ypred_sc)
rmse = root_mean_squared_error(y_val_sc['tphl'], ypred_sc)
print(f'clf: ANN, rmse: {rmse}')
print(f'clf: ANN, mse: {mse}')
# Out:
# 989/989 ━━━━━━━━━━━━━━━━━━━━ 1s 527us/step
# clf: ANN, rmse: 0.009779704071700748
# clf: ANN, mse: 9.564261173004018e-05

# %%
r2 = r2_score(y_val_sc['tphl'], ypred_sc)
print(f'R²: {r2}')
# Out:
# R²: 0.9999046738356174

# %%
score(model, X_val_sc, y_val_sc['tphl'], 'mlp_S_K', 'tphl', 'val')
# Out:
# 989/989 ━━━━━━━━━━━━━━━━━━━━ 1s 492us/step
# {'r2': 0.9999046738356174,
#  'rmse': 0.009779704071700748,
#  'mse': 9.564261173004018e-05}

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=ypred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=y_val_sc['tphl'], label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -K Validation, TpHL')
ax.legend()
plt.savefig(f"{plots_dir}/MLP_S_K_VAL_TPHL.png")
plt.show()
plt.close()

# %% [markdown]
# #### Predicting TPLH

# %%
K.clear_session()
model.compile(loss="mean_squared_error", optimizer="adam")
history = model.fit(X_train_sc, y_train_sc['tplh'], epochs=500, batch_size=32, validation_data=(X_val_sc, y_val_sc['tplh']),
                    shuffle=True, callbacks=[early_stop])
# Out:
# Epoch 1/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0479 - val_loss: 8.8328e-04
# Epoch 2/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.7280e-04 - val_loss: 9.9334e-04
# Epoch 3/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.8530e-04 - val_loss: 7.0823e-04
# Epoch 4/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.3751e-04 - val_loss: 0.0011
# Epoch 5/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.4954e-04 - val_loss: 8.2674e-04
# Epoch 6/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.1081e-04 - val_loss: 0.0010
# Epoch 7/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 8.8560e-04 - val_loss: 0.0010
# Epoch 8/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 8.5412e-04 - val_loss: 9.7614e-04
# Epoch 9/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 8.5558e-04 - val_loss: 7.0169e-04
# Epoch 10/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 8.5387e-04 - val_loss: 6.8401e-04
# Epoch 11/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 8.2094e-04 - val_loss: 0.0010
# Epoch 12/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 8.2002e-04 - val_loss: 6.8628e-04
# Epoch 13/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 8.2714e-04 - val_loss: 9.1309e-04
# Epoch 14/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 8.2773e-04 - val_loss: 6.6342e-04
# Epoch 15/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 8.0742e-04 - val_loss: 7.6171e-04

# %%
ypred_sc = model.predict(X_val_sc)
mse = mean_squared_error(y_val_sc['tplh'], ypred_sc)
rmse = root_mean_squared_error(y_val_sc['tplh'], ypred_sc)
print(f'clf: ANN, rmse: {rmse}')
print(f'clf: ANN, mse: {mse}')
# Out:
# 989/989 ━━━━━━━━━━━━━━━━━━━━ 1s 606us/step
# clf: ANN, rmse: 0.029719985665014576
# clf: ANN, mse: 0.0008832775479286719

# %%
r2 = r2_score(y_val_sc['tplh'], ypred_sc)

print(f'R²: {r2}')
# Out:
# R²: 0.9990930815246136

# %%
score(model, X_val_sc, y_val_sc['tplh'], 'mlp_S_K', 'tplh', 'val')
# Out:
# 989/989 ━━━━━━━━━━━━━━━━━━━━ 1s 499us/step
# {'r2': 0.9990930815246136,
#  'rmse': 0.029719985665014576,
#  'mse': 0.0008832775479286719}

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=ypred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=y_val_sc['tplh'], label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -K Validation, TpLH')
ax.legend()
plt.savefig(f"{plots_dir}/MLP_S_K_VAL_TPLH.png")
plt.show()
plt.close()

# %% [markdown]
# #### Predicting Energy

# %%
K.clear_session()
model.compile(loss="mean_squared_error", optimizer="adam")
history = model.fit(X_train_sc, y_train_sc['energy'], epochs=500, batch_size=32, validation_data=(X_val_sc, y_val_sc['energy']),
                    shuffle=True, callbacks=[early_stop])
# Out:
# Epoch 1/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0425 - val_loss: 0.0035
# Epoch 2/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 3/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 4/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 5/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 6/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 7/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 8/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 9/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 10/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 11/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 12/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 13/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 14/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 15/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0017 - val_loss: 0.0017

# %%
ypred_sc = model.predict(X_val_sc)
mse = mean_squared_error(y_val_sc['energy'], ypred_sc)
rmse = root_mean_squared_error(y_val_sc['energy'], ypred_sc)
print(f'clf: ANN, rmse: {rmse}')
print(f'clf: ANN, mse: {mse}')
# Out:
# 989/989 ━━━━━━━━━━━━━━━━━━━━ 1s 591us/step
# clf: ANN, rmse: 0.05905507098568015
# clf: ANN, mse: 0.003487501409123721

# %%
r2 = r2_score(y_val_sc['energy'], ypred_sc)
print(f'R²: {r2}')
# Out:
# R²: 0.9965079699833803

# %%
score(model, X_val_sc, y_val_sc['energy'], 'mlp_S_K', 'corrent', 'val')
# Out:
# 989/989 ━━━━━━━━━━━━━━━━━━━━ 1s 509us/step
# {'r2': 0.9965079699833803,
#  'rmse': 0.05905507098568015,
#  'mse': 0.003487501409123721}

# %%
fig, ax = plt.subplots(1,1, figsize = (10,7))
sns.kdeplot(data=ypred_sc, label = 'predicted', ax = ax,color = 'royalblue')
sns.kdeplot(data=y_val_sc['energy'], label = 'true', ax = ax, color = 'red')
ax.set_title('MLP -S -K Validation, Corrent')
ax.legend()
plt.savefig(f"{plots_dir}/MLP_S_K_VAL_CORRENT.png")
plt.show()
plt.close()

# %% [markdown]
# ### Multi-output model

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(100, activation="relu", input_shape=X_train_sc.shape[1:]),
    tf.keras.layers.Dense(50, activation='relu'),
    tf.keras.layers.Dense(3)
])

K.clear_session()
model.compile(loss="mean_squared_error", optimizer="adam")
history = model.fit(X_train_sc, y_train_sc, epochs=500, batch_size=32, validation_data=(X_val_sc, y_val_sc), 
                    shuffle=True, callbacks=[early_stop])
# Out:
# Epoch 1/500
# /home/eduarda/Repos/jupyter_ic/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0402 - val_loss: 0.0026
# Epoch 2/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 3/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 4/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 5/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 6/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 7/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 8/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 9/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 10/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 11/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 12/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 13/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 14/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 15/500
# 2007/2007 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0012 - val_loss: 0.0011

# %% [markdown]
# print(model.outputs)

# %% [markdown]
# - input neurons:
# - hidden layers:
# - neurons per hidden layes:
# - hidden activation:
# - output activation:
# - loss function:
#
# - activation function for hidden layer:
# - solver:
# - max_iter:
# - shuffle:
# - validation_fraction:
# - n_iter_no_change:
# - hidden layer_sizes:
# - early_stopping:
# - random_state:
# - verbose:
#
# - learning_rate

# %%
ypred_sc = model.predict(X_val_sc)
mse = mean_squared_error(y_val_sc, ypred_sc)
rmse = root_mean_squared_error(y_val_sc, ypred_sc)
print(f'clf: ANN, rmse: {rmse}')
print(f'clf: ANN, mse: {mse}')
# Out:
# 989/989 ━━━━━━━━━━━━━━━━━━━━ 1s 592us/step
# clf: ANN, rmse: 0.049645084887742996
# clf: ANN, mse: 0.0025575722102075815

# %%
r2 = r2_score(y_val_sc, ypred_sc)

print(f'R²: {r2}')
# Out:
# R²: 0.9974239468574524

# %%
score(model, X_val_sc, y_val_sc, 'mlp_M_K', 'all', 'val')
# Out:
# 989/989 ━━━━━━━━━━━━━━━━━━━━ 1s 614us/step
# {'r2': 0.9974239468574524,
#  'rmse': 0.049645084887742996,
#  'mse': 0.0025575722102075815}

# %%
variables = ['TPHL', 'TPLH', 'CORRENT']
#scatter_plot_multi_output_regression_results(ypred_sc, y_val_sc, variables, "MLP_M_K_VALL_ALL_SCATTER", "MLP_M_K_VALL_ALL_SCATTER")

# %%
kde_plot_multi_output_regression_results(ypred_sc, y_val_sc, variables, "MLP_M_K_VAL_ALL", "MLP_M_K_VALL_ALL")

# %% [markdown]
# ## Results

# %%
results = pd.DataFrame.from_dict(scores, orient='index')
results.index.names = ['target', 'model', 'set']

path = os.path.join('../../../../../outputs/CMOS/32nm/NOT/MLP_Regressor', 'results_mlps')

from datetime import datetime

current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
path_with_time = f"{path}_{current_time}.csv"
results.to_csv(path_with_time, index_label='target_name')

results
# Out:
#                               r2      rmse       mse
# target    model   set
# mlp_S_SKL tphl    val   0.999675  0.018046  0.000326
#                   test  0.999657  0.018645  0.000348
#           tplh    val   0.999273  0.026609  0.000708
#                   test  0.999269  0.027004  0.000729
#           corrent val   0.998177  0.042669  0.001821
#                   test  0.998194  0.042582  0.001813
# mlp_M_SKL all     val   0.998644  0.035020  0.001348
#                   test  0.998632  0.035425  0.001373
# mlp_S_K   tphl    val   0.999905  0.009780  0.000096
#           tplh    val   0.999093  0.029720  0.000883
#           corrent val   0.996508  0.059055  0.003488
# mlp_M_K   all     val   0.997424  0.049645  0.002558
